# %%
"""def say_hello():
    print("hello ji")

say_hello()"""

"""def greet(name):
    print(name)
greet( "sagar")
greet("aman")
greet("tina")"""

"""tensor`s  - setup """
# Out:
# 'tensor`s  - setup '
